# %%
import cv2
import numpy as np
import tensorflow as tf
import glob 
import os
import time
import boto3
import json
import io
import botocore
import base64
import matplotlib.pyplot as plt

try:
    import Image, ImageDraw, ImageFont
except ImportError:
    from PIL import Image, ImageDraw, ImageFont

# %%
from helpers import InPainting

# %%
model = InPainting()

# %%
image = Image.open('test_images/image_5.jpg')
output = model.run_main(image)

# %%
f = plt.figure(figsize=(20,20))
f.add_subplot(1,2,1)
plt.imshow(image)
f.add_subplot(1,2,2)
plt.imshow(output)
plt.show(block=True)
